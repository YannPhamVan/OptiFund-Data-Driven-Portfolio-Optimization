# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader as pdr
import time
from datetime import date

# %%
dl_yf = yf.download(tickers = ["^W5000", "^VXN", "^VXD", "^VVIX", "^VIX", "^STOXX", "^SPXEW", "^SOX", "^SKEW", "^RUT", "^OEX", "^NBI", "^N150", "^IBEX", "^CN20", "^BVSP", "^BSESN", "^NDX", "^DJU", "^DJT", "^OSEAX", "^OMXC25", "^AEX", "^STI", "^NZ50", "^AORD", "^AXJO", "^HSI", "^N225", "000001.SS", "^N100", "^GDAXI", "^FTSE", "^IXIC", "^DJI", "^GSPC", "^FCHI", "^STOXX50E"],
                    period = "max",
                    interval = "1d")["Close"]
# Out:
# [*********************100%***********************]  38 of 38 completed

# %%
dl_yf = dl_yf["Close"]

# %%
dl_yf
# Out:
# Ticker        000001.SS        ^AEX        ^AORD   ^AXJO        ^BSESN  \
# Date
# 1927-12-30          NaN         NaN          NaN     NaN           NaN
# 1928-01-03          NaN         NaN          NaN     NaN           NaN
# 1928-01-04          NaN         NaN          NaN     NaN           NaN
# 1928-01-05          NaN         NaN          NaN     NaN           NaN
# 1928-01-06          NaN         NaN          NaN     NaN           NaN
# ...                 ...         ...          ...     ...           ...
# 2025-03-25  3369.976074  921.000000  8166.700195  7942.5  78017.187500
# 2025-03-26  3368.697021  917.090027  8225.099609  7999.0  77288.500000
# 2025-03-27  3373.749023  914.679993  8185.500000  7969.0  77606.429688
# 2025-03-28  3351.306885  907.460022  8195.500000  7982.0  77414.921875
# 2025-03-31          NaN         NaN          NaN     NaN           NaN
#
# Ticker         ^BVSP         ^CN20          ^DJI          ^DJT         ^DJU  \
# Date
# ...

# %%
dl_yf.to_csv("dl_yf", index=False)
