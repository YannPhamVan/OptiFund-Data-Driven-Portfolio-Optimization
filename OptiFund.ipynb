# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader as pdr
import time
from datetime import date

# %%
dl_yf = yf.download(tickers = ["^W5000", "^VXN", "^VXD", "^VVIX", "^VIX", "^STOXX", "^SPXEW", "^SOX", "^SKEW", "^RUT", "^OEX", "^NBI", "^N150", "^IBEX", "^CN20", "^BVSP", "^BSESN", "^NDX", "^DJU", "^DJT", "^OSEAX", "^OMXC25", "^AEX", "^STI", "^NZ50", "^AORD", "^AXJO", "^HSI", "^N225", "000001.SS", "^N100", "^GDAXI", "^FTSE", "^RUT", "^IXIC", "^DJI", "^GSPC", "^FCHI", "^STOXX50E"],
                    period = "max",
                    interval = "1d")
# Out:
# [*********************100%***********************]  38 of 38 completed

# %%
dl_yf.Close.T
# Out:
# Date       1927-12-30  1928-01-03  1928-01-04  1928-01-05  1928-01-06  \
# Ticker
# 000001.SS         NaN         NaN         NaN         NaN         NaN
# ^AEX              NaN         NaN         NaN         NaN         NaN
# ^AORD             NaN         NaN         NaN         NaN         NaN
# ^AXJO             NaN         NaN         NaN         NaN         NaN
# ^BSESN            NaN         NaN         NaN         NaN         NaN
# ^BVSP             NaN         NaN         NaN         NaN         NaN
# ^CN20             NaN         NaN         NaN         NaN         NaN
# ^DJI              NaN         NaN         NaN         NaN         NaN
# ^DJT              NaN         NaN         NaN         NaN         NaN
# ^DJU              NaN         NaN         NaN         NaN         NaN
# ^FCHI             NaN         NaN         NaN         NaN         NaN
# ^FTSE             NaN         NaN         NaN         NaN         NaN
# ...
