# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 4
#       2 import pandas as pd
#       3 import yfinance as yf
# ----> 4 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
nasdaq100 = yf.download(tickers = ["NDX", "DAX"],
                        period = "max",
                        interval = "1d")
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
nasdaq100
# Out:
# Price           Close                     High                      Low  \
# Ticker            DAX           NDX        DAX           NDX        DAX
# Date
# 2014-10-23  19.979094           NaN  19.994919           NaN  19.852493
# 2014-10-24  19.931622           NaN  19.931622           NaN  19.892058
# 2014-10-27  19.803440           NaN  19.803440           NaN  19.803440
# 2014-10-28  20.184824           NaN  20.184824           NaN  20.129437
# 2014-10-29  20.311422           NaN  20.311422           NaN  20.303510
# ...               ...           ...        ...           ...        ...
# 2025-03-24  40.099998  20180.439453  40.310001  20180.439453  39.880001
# 2025-03-25  40.490002  20287.830078  40.599998  20287.830078  40.330002
# 2025-03-26  39.630001  19916.990234  40.259998  19916.990234  39.479000
# 2025-03-27  39.650002           NaN  39.769001           NaN  39.349998
# 2025-03-28  39.425400           NaN  39.630001           NaN  39.221001
#
# ...
